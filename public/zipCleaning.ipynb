# %%
import pandas as pd
import json

# %%
zip_data=pd.read_csv("zipCodes.csv")
moco_zip=["20810","20812","20811","20814","20816","20815","20818","20817","20825","20824","20830","20827","20833","20832","20838","20837","20841","20839","20847","20842","20849","20848","20851","20850","20853","20852","20855","20854","20859","20857","20861","20860","20866","20862","20871","20868","20874","20872","20876","20875","20878","20877","20880","20879","20883","20058","20882","20885","20884","20886","20895","20896","20899","20898","20902","20901","20904","20903","20906","20905","20907","20910","20912","20914","20916"]

# %%
zip_data=zip_data[zip_data['ZIP'].isin(moco_zip)]

# %%
zip_data
# Out:
#         ZIP        LAT        LNG
# 6438  20812  38.967041 -77.143881
# 6439  20814  39.004989 -77.101490
# 6440  20815  38.983386 -77.079346
# 6441  20816  38.956950 -77.120006
# 6442  20817  38.997272 -77.151816
# 6443  20818  38.973445 -77.162497
# 6444  20832  39.150347 -77.078240
# 6445  20833  39.207175 -77.054670
# 6446  20837  39.116506 -77.407115
# 6447  20838  39.218101 -77.390831
# 6448  20839  39.188307 -77.434971
# 6449  20841  39.191853 -77.327521
# 6450  20842  39.199879 -77.415267
# 6451  20850  39.091338 -77.182294
# 6452  20851  39.079082 -77.121858
# 6453  20852  39.051991 -77.121931
# 6454  20853  39.101713 -77.094562
# 6455  20854  39.032772 -77.220830
# 6456  20855  39.133184 -77.134383
# 6457  20860  39.142366 -77.025412
# 6458  20861  39.149774 -76.998236
# 6459  20862  39.181230 -77.018806
# 6460  20866  39.109275 -76.933973
# 6461  20868  39.126395 -76.969321
# 6462  20871  39.261341 -77.282547
# 6463  20872  39.294465 -77.216125
# ...

# %%
zip_dic={}
for i in range(len(zip_data)):
    zip_dic[int(zip_data.iloc[i]["ZIP"])]={"lat":zip_data.iloc[i]["LAT"],"lng":zip_data.iloc[i]["LNG"]}

# %%
for z in zip_dic:
    print(z)

# %%
with open("zip.json", "w") as outfile:  
    json.dump(zip_dic, outfile)

# %%
moco_zip=[20810
    20812
    20811
    20814
    20816
    20815
    20818
    20817
    20825
    20824
    20830
    20827
    20833
    20832
    20838
    20837
    20841
    20839
    20847
    20842
    20849
    20848
    20851
    20850
    20853
    20852
    20855
    20854
    20859
    20857
    20861
    20860
    20866
    20862
    20871
    20868
    20874
    20872
    20876
    20875
    20878
    20877
    20880
    20879
    20883
    20058
    20882
    20885
    20884
    20886
    20895
    20896
    20899
    20898
    20902
    20901
    20904
    20903
    20906
    20905
    20907
    20910
    20912
    20914
    20916]
